# %%
pip install langchain-pinecone
# Out:
# Collecting langchain-pinecone
#   Downloading langchain_pinecone-0.2.13-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.34 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-pinecone) (1.2.5)
# Collecting pinecone<8.0.0,>=6.0.0 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy!=2.0.2,>=1.26.4 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-pinecone) (2.0.1)
# Collecting langchain-openai>=0.3.11 (from langchain-pinecone)
#   Downloading langchain_openai-1.1.6-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: httpx>=0.28.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-pinecone) (0.28.1)
# Collecting simsimd>=5.9.11 (from langchain-pinecone)
#   Downloading simsimd-6.5.12-cp310-cp310-win_amd64.whl.metadata (71 kB)
# Requirement already satisfied: pydantic>=2.11.1 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-pinecone) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.5.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\.conda\envs\genai\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.25.0)
# Requirement already satisfied: anyio in c:\users\admin\.conda\envs\genai\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (4.10.0)
# Requirement already satisfied: certifi in c:\users\admin\.conda\envs\genai\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\.conda\envs\genai\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (1.0.9)
# Requirement already satisfied: idna in c:\users\admin\.conda\envs\genai\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\.conda\envs\genai\lib\site-packages (from httpcore==1.*->httpx>=0.28.0->langchain-pinecone) (0.16.0)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\admin\.conda\envs\genai\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\admin\.conda\envs\genai\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.1)
# Requirement already satisfied: aiohttp>=3.9.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.13.2)
# Collecting aiohttp-retry<3.0.0,>=2.9.1 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from pydantic>=2.11.1->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\.conda\envs\genai\lib\site-packages (from pydantic>=2.11.1->langchain-pinecone) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\.conda\envs\genai\lib\site-packages (from pydantic>=2.11.1->langchain-pinecone) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\.conda\envs\genai\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.22.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\admin\.conda\envs\genai\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (2.14.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai>=0.3.11->langchain-pinecone)
#   Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\admin\.conda\envs\genai\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\admin\.conda\envs\genai\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\admin\.conda\envs\genai\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\admin\.conda\envs\genai\lib\site-packages (from anyio->httpx>=0.28.0->langchain-pinecone) (1.3.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\admin\.conda\envs\genai\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.3.11->langchain-pinecone) (2025.11.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\genai\lib\site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: colorama in c:\users\admin\.conda\envs\genai\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (0.4.6)
# Downloading langchain_pinecone-0.2.13-py3-none-any.whl (26 kB)
# Downloading pinecone-7.3.0-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.6 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/587.6 kB ? eta -:--:--
#    ---------------------------------------- 587.6/587.6 kB 1.4 MB/s  0:00:00
# Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl (259 kB)
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading langchain_openai-1.1.6-py3-none-any.whl (84 kB)
# Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/879.4 kB ? eta -:--:--
#    ---------------------------------------- 879.4/879.4 kB 2.1 MB/s  0:00:00
# Downloading simsimd-6.5.12-cp310-cp310-win_amd64.whl (87 kB)
# Installing collected packages: simsimd, tiktoken, pinecone-plugin-assistant, pinecone, aiohttp-retry, langchain-openai, langchain-pinecone
#
#    ----- ---------------------------------- 1/7 [tiktoken]
#    ----- ---------------------------------- 1/7 [tiktoken]
#    ----- ---------------------------------- 1/7 [tiktoken]
#    ----- ---------------------------------- 1/7 [tiktoken]
#    ----- ---------------------------------- 1/7 [tiktoken]
#    ----- ---------------------------------- 1/7 [tiktoken]
#   Attempting uninstall: pinecone-plugin-assistant
#    ----- ---------------------------------- 1/7 [tiktoken]
#     Found existing installation: pinecone-plugin-assistant 3.0.1
#    ----- ---------------------------------- 1/7 [tiktoken]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#     Uninstalling pinecone-plugin-assistant-3.0.1:
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#       Successfully uninstalled pinecone-plugin-assistant-3.0.1
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#   Attempting uninstall: pinecone
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#     Found existing installation: pinecone 8.0.0
#    ----------- ---------------------------- 2/7 [pinecone-plugin-assistant]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#     Uninstalling pinecone-8.0.0:
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#       Successfully uninstalled pinecone-8.0.0
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ----------------- ---------------------- 3/7 [pinecone]
#    ---------------------- ----------------- 4/7 [aiohttp-retry]
#    ---------------------- ----------------- 4/7 [aiohttp-retry]
#    ---------------------- ----------------- 4/7 [aiohttp-retry]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langchain-openai]
#    ---------------------------------- ----- 6/7 [langchain-pinecone]
#    ---------------------------------- ----- 6/7 [langchain-pinecone]
#    ---------------------------------- ----- 6/7 [langchain-pinecone]
#    ---------------------------------- ----- 6/7 [langchain-pinecone]
#    ---------------------------------------- 7/7 [langchain-pinecone]
#
# Successfully installed aiohttp-retry-2.9.1 langchain-openai-1.1.6 langchain-pinecone-0.2.13 pinecone-7.3.0 pinecone-plugin-assistant-1.8.0 simsimd-6.5.12 tiktoken-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv  # ✅ Added for .env support
# Load environment variables from .env file
load_dotenv()
from pinecone import Pinecone, ServerlessSpec
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Pinecone as LangchainPinecone
from langchain_core.prompts import PromptTemplate
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline
import warnings
from langchain_pinecone import PineconeVectorStore

warnings.filterwarnings('ignore')

print("✅ All libraries imported successfully")
# Out:
# ✅ All libraries imported successfully

# %%
print("Initializing Pinecone")
try:
    pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
    INDEX_NAME = "chat-with-pdf"

    exsting_indexes = [idx.name for idx in pc.list_indexes()]

    if INDEX_NAME not in exsting_indexes:
        print("creating new index")
        pc.create_index(
            name = INDEX_NAME,
            dimension=384,
            metric="cosine",
            spec=ServerlessSpec(
                cloud="aws",
                region="us-east-1"
            )
                        )
        print("waiting for index to be ready...")
    else:
        print("using existing index:{INDEX_NAME}")
    
    index = pc.Index(INDEX_NAME)
except Exception as e:
    print("pinecone intialization failed")
    raise
# Out:
# Initializing Pinecone
# creating new index
# waiting for index to be ready...

# %%
# Load PDF document

PDF_PATH = 'F:\Gen AI\GenAI-MiniProjects\Chat With PDF/hadoop.pdf'
try:
    loader = PyPDFLoader(PDF_PATH)
    documents = loader.load()

    if not documents:
        raise ValueError("no content found in PDF")
    print(f"✅ Loaded {len(documents)} pages from PDF")
    print(f"📖 First page preview: {documents[0].page_content[:200]}...")
    
except FileNotFoundError:
    print(f"❌ File not found: {PDF_PATH}")
    print("💡 Please place your PDF file in the same directory or update PDF_PATH")
    raise
except Exception as e:
    print(f"❌ Error loading PDF: {e}")
    raise
# Out:
# ✅ Loaded 3 pages from PDF
# 📖 First page preview: Hadoop  is  an  open-source  framework  for  storing  and  processing  large-scale  data  across
# distributed
#
# clusters
#
# using
#
# commodity
#
# hardware.
#
# The
#
# Hadoop
#
# Ecosystem
#
# is
#
# a
#
# suite
#
# ...

# %%
# Split text into Chunks

try:
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = 1000,
        chunk_overlap = 200,
        length_function = len,
        separators = ["\n\n","\n",""," "]
    )
    chunks = text_splitter.split_documents(documents)


except Exception as e:
    raise

# %%
# Intialize EMbedding Models

embeddings = HuggingFaceEmbeddings(
    model_name = "sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device':'cpu'},
    encode_kwargs = {'normalize_embeddings':True}
)

#Test Embeddings

test_embed = embeddings.embed_query("test")
print(f"✅ Embeddings model loaded (dimension: {len(test_embed)})")
# Out:
# ✅ Embeddings model loaded (dimension: 384)

# %%
# Store EMbeddings in Pinecone

vectorstore = PineconeVectorStore.from_documents(
    documents=chunks,
    embedding=embeddings,
    index_name = INDEX_NAME
)

print("Embedding stores successfully")

# create retriever
retriever = vectorstore.as_retriever(
    search_type = "similarity",
    search_kwargs = {"k":3}
)

print("✅ Retriever created (will fetch top 3 relevant chunks)")
# Out:
# Embedding stores successfully
# ✅ Retriever created (will fetch top 3 relevant chunks)

# %%
# Load Language Model
hf_pipeline = pipeline(
    "text2text-generation",
    model = "google/flan-t5-small",
    max_length = 200,
    temperature = 0.7,
    do_sample=True,
    top_p=0.9
)
llm = HuggingFacePipeline(pipeline=hf_pipeline)

#test the model
test_response = llm.invoke("Hello, How are you?")
print("✅ Language model loaded successfully")
print(f"🧪 Test response: {test_response[:50]}...")
# Out:
# Device set to use cpu
# ✅ Language model loaded successfully
# 🧪 Test response: Hello, how are you?...

# %%
# Create Prompt Template and chain
prompt = PromptTemplate(
    input_variables=['context','question'],
    template="""Answer the question based only on the context below. If the answer is not in the context, say "I don't know based on the provided document."
    Context: {context}
    Question:{question}
    Answer:"""
    )

# Create chain using LangChain Expression Language (LCEL)
chain = prompt | llm

print("Chain created successfully")
# Out:
# Chain created successfully

# %%
# Helper function for chat

def chat_with_pdf(question):
    if not question.strip():
        return "Enter the valid question"
    
    # retrieve relevent documents
    docs = retriever.invoke(question)

    if not docs:
        return "I dont know based on the provides documents"
    
    context = "\n\n".join([doc.page_content for doc in docs])

    #general response
    response = chain.invoke({
        "context":context,
        "question":question
    })

    # clean response
    answer = response.strip() if isinstance(response, str) else str(response).strip()

    return answer

# %%
# Test single query
test_question = "what is the document about?"
answer = chat_with_pdf(test_question)

print(f"Question: {test_question}")
print(f"Answer: {answer}\n")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (602 > 512). Running this sequence through the model will result in indexing errors
# Question: what is the document about?
# Answer: HBase is a NoSQL database in Hadoop ecosystem that supports all data types and handles large datasets efficiently, similar to Google’s BigTable. It is ideal for fast read/write operations on small portions of data within massive datasets. HBase offers a fault-tolerant and efficient way to store and retrieve data quickly, making it useful for real-time lookups. Other Components Apart from core components, Hadoop also includes important tools like: Solr & Lucene: Used for searching and indexing. Lucene (Java-based) offers features like spell check and Solr acts as its powerful search platform. Zookeeper: Handles coordination and synchronization between Hadoop components, ensuring consistent communication and grouping across the cluster. storage and processing: HDFS HDFS is a core component of Hadoop ecosystem, designed to store large volumes of structured or unstructured data across

# %%
# Interactive chat Loop
while True:
    query = input("You: ").strip()

    if query.lower() in ['exit','quit','q']:
        print("\n👋 Thank you for using Chat with PDF!")
        break

    if not query:
        print("⚠️ Please enter a question\n")
        continue

    # Get answer
    print("\n🤔 Thinking...\n")
    answer = chat_with_pdf(query)
    print(f"Bot: {answer}\n")
    print("-" * 60 + "\n")
# Out:
# 🤔 Thinking...
#
# Bot: YARN (Yet Another Resource Negotiator): Manages cluster resources and job scheduling. MapReduce: A programming model for batch data processing. Hive & Pig: High-level tools for querying and analyzing large datasets. HBase: A NoSQL database for real-time read/write access. Mahout & Spark MLlib: Libraries for scalable machine learning. Solr & Lucene: Tools for full-text search and indexing. Zookeeper: Manages coordination and configuration across the cluster. Oozie: A workflow scheduler for managing Hadoop jobs. HadoopEcosystem Key Components of Hadoop Ecosystem
#
# ------------------------------------------------------------
#
#
# 👋 Thank you for using Chat with PDF!
